# %%
missing_files = ("1_1_2_6_25", "2_1_1_4_24", "2_1_1_6_24", "2_1_1_7_25", "2_2_1_5_30", "3_1_1_6_25", "3_1_2_4_30", "3_2_1_5_30", "4_1_2_8_25", "5_1_2_3_25", "6_1_2_2_30", "6_1_2_5_30", "6_2_1_2_25",
                 "6_2_2_13_30", "6_2_2_6_30")

# %%
import os
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

FILENAME_PATH = r""
CSV_MANHATTAN_INPUT_PATH = r""
CSV_MANHATTAN28_OUTPUT_PATH = r""

temp_files = []
train_files = []

for root, dirs, files in os.walk(FILENAME_PATH):
    for filename in files:
        if filename.endswith(".mp4"):
            if filename.startswith(missing_files):
                temp_files.append(filename.split('.')[0])
            else:
                train_files.append(filename.split('.')[0])

train_files, test_files = train_test_split(
    train_files, test_size=0.2, random_state=42)
train_files = train_files + temp_files

train = []
for filename in train_files:
    for i in range(1, 6):
        try:
            t = pd.read_csv(CSV_MANHATTAN_INPUT_PATH + "\\" + filename +
                            '_' + str(i) + "_m.csv", header=None).head(240)
        except FileNotFoundError:
            continue
        t = t.to_numpy().flatten()
        t = np.insert(t, 0, filename.split('_')[0]).reshape(1, 6721)
        train.append(t)
train = np.concatenate(train, axis=0)

test = []
for filename in test_files:
    for i in range(1, 6):
        try:
            t = pd.read_csv(CSV_MANHATTAN_INPUT_PATH + "\\" + filename +
                            '_' + str(i) + "_m.csv", header=None).head(240)
        except FileNotFoundError:
            continue
        t = t.to_numpy().flatten()
        t = np.insert(t, 0, filename.split('_')[0]).reshape(1, 6721)
        test.append(t)
test = np.concatenate(test, axis=0)

np.random.seed(42)
np.random.shuffle(train)
np.random.shuffle(test)

os.chdir(CSV_MANHATTAN28_OUTPUT_PATH)
np.savetxt("train.csv", train, fmt="%d", delimiter=',')
np.savetxt("test.csv", test, fmt="%d", delimiter=',')

# %%
import os
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

FILENAME_PATH = r""
CSV_MANHATTAN_INPUT_PATH = r""
CSV_MANHATTAN24_OUTPUT_PATH = r""

temp_files = []
train_files = []

for root, dirs, files in os.walk(FILENAME_PATH):
    for filename in files:
        if filename.endswith(".mp4"):
            if filename.startswith(missing_files):
                temp_files.append(filename.split('.')[0])
            else:
                train_files.append(filename.split('.')[0])

train_files, test_files = train_test_split(
    train_files, test_size=0.2, random_state=42)
train_files = train_files + temp_files

train = []
for filename in train_files:
    for i in range(1, 6):
        try:
            t = pd.read_csv(CSV_MANHATTAN_INPUT_PATH + "\\" + filename +
                            '_' + str(i) + "_m.csv", header=None).head(240)
        except FileNotFoundError:
            continue
        t = t.drop([7, 13, 25, 27], axis=1)
        t = t.to_numpy().flatten()
        t = np.insert(t, 0, filename.split('_')[0]).reshape(1, 5761)
        train.append(t)
train = np.concatenate(train, axis=0)

test = []
for filename in test_files:
    for i in range(1, 6):
        try:
            t = pd.read_csv(CSV_MANHATTAN_INPUT_PATH + "\\" + filename +
                            '_' + str(i) + "_m.csv", header=None).head(240)
        except FileNotFoundError:
            continue
        t = t.drop([7, 13, 25, 27], axis=1)
        t = t.to_numpy().flatten()
        t = np.insert(t, 0, filename.split('_')[0]).reshape(1, 5761)
        test.append(t)
test = np.concatenate(test, axis=0)

np.random.seed(42)
np.random.shuffle(train)
np.random.shuffle(test)

os.chdir(CSV_MANHATTAN24_OUTPUT_PATH)
np.savetxt("train.csv", train, fmt="%d", delimiter=',')
np.savetxt("test.csv", test, fmt="%d", delimiter=',')

# %%
import os
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

FILENAME_PATH = r""
CSV_EUCLIDEAN_INPUT_PATH = r""
CSV_EUCLIDEAN28_OUTPUT_PATH = r""

temp_files = []
train_files = []

for root, dirs, files in os.walk(FILENAME_PATH):
    for filename in files:
        if filename.endswith(".mp4"):
            if filename.startswith(missing_files):
                temp_files.append(filename.split('.')[0])
            else:
                train_files.append(filename.split('.')[0])

train_files, test_files = train_test_split(
    train_files, test_size=0.2, random_state=42)
train_files = train_files + temp_files

train = []
for filename in train_files:
    for i in range(1, 6):
        try:
            t = pd.read_csv(CSV_EUCLIDEAN_INPUT_PATH + "\\" + filename +
                            '_' + str(i) + "_m.csv", header=None).head(240)
        except FileNotFoundError:
            continue
        t = t.to_numpy().flatten()
        t = np.insert(t, 0, filename.split('_')[0]).reshape(1, 6721)
        train.append(t)
train = np.concatenate(train, axis=0)

test = []
for filename in test_files:
    for i in range(1, 6):
        try:
            t = pd.read_csv(CSV_EUCLIDEAN_INPUT_PATH + "\\" + filename +
                            '_' + str(i) + "_m.csv", header=None).head(240)
        except FileNotFoundError:
            continue
        t = t.to_numpy().flatten()
        t = np.insert(t, 0, filename.split('_')[0]).reshape(1, 6721)
        test.append(t)
test = np.concatenate(test, axis=0)

np.random.seed(42)
np.random.shuffle(train)
np.random.shuffle(test)

os.chdir(CSV_EUCLIDEAN28_OUTPUT_PATH)
np.savetxt("train.csv", train, fmt="%d", delimiter=',')
np.savetxt("test.csv", test, fmt="%d", delimiter=',')

# %%
import os
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

FILENAME_PATH = r""
CSV_EUCLIDEAN_INPUT_PATH = r""
CSV_EUCLIDEAN24_OUTPUT_PATH = r""

temp_files = []
train_files = []

for root, dirs, files in os.walk(FILENAME_PATH):
    for filename in files:
        if filename.endswith(".mp4"):
            if filename.startswith(missing_files):
                temp_files.append(filename.split('.')[0])
            else:
                train_files.append(filename.split('.')[0])

train_files, test_files = train_test_split(
    train_files, test_size=0.2, random_state=42)
train_files = train_files + temp_files

train = []
for filename in train_files:
    for i in range(1, 6):
        try:
            t = pd.read_csv(CSV_EUCLIDEAN_INPUT_PATH + "\\" + filename +
                            '_' + str(i) + "_m.csv", header=None).head(240)
        except FileNotFoundError:
            continue
        t = t.drop([7, 13, 25, 27], axis=1)
        t = t.to_numpy().flatten()
        t = np.insert(t, 0, filename.split('_')[0]).reshape(1, 5761)
        train.append(t)
train = np.concatenate(train, axis=0)

test = []
for filename in test_files:
    for i in range(1, 6):
        try:
            t = pd.read_csv(CSV_EUCLIDEAN_INPUT_PATH + "\\" + filename +
                            '_' + str(i) + "_m.csv", header=None).head(240)
        except FileNotFoundError:
            continue
        t = t.drop([7, 13, 25, 27], axis=1)
        t = t.to_numpy().flatten()
        t = np.insert(t, 0, filename.split('_')[0]).reshape(1, 5761)
        test.append(t)
test = np.concatenate(test, axis=0)

np.random.seed(42)
np.random.shuffle(train)
np.random.shuffle(test)

os.chdir(CSV_EUCLIDEAN24_OUTPUT_PATH)
np.savetxt("train.csv", train, fmt="%d", delimiter=',')
np.savetxt("test.csv", test, fmt="%d", delimiter=',')

# %%
x_train = pd.read_csv(CSV_MANHATTAN28_OUTPUT_PATH +
                      r"\train.csv", header=None)
x_test = pd.read_csv(CSV_MANHATTAN28_OUTPUT_PATH +
                     r"\test.csv", header=None)

y_train = x_train.iloc[:, 0]
x_train = x_train.drop(0, axis=1)
y_test = x_test.iloc[:, 0]
x_test = x_test.drop(0, axis=1)

x_val, x_test, y_val, y_test = train_test_split(
    x_test, y_test, test_size=0.5, random_state=42)

y_train = y_train.to_numpy(dtype=np.int32)
x_train = x_train.to_numpy(dtype=np.float32)
y_val = y_val.to_numpy(np.int32)
x_val = x_val.to_numpy(np.float32)
y_test = y_test.to_numpy(np.int32)
x_test = x_test.to_numpy(np.float32)

print("x_train:", x_train.shape, x_train.dtype)
print("y_train:", y_train.shape, y_train.dtype)
print("x_val:", x_val.shape, x_val.dtype)
print("y_val:", y_val.shape, y_val.dtype)
print("x_test:", x_test.shape, x_test.dtype)
print("y_test:", y_test.shape, y_test.dtype)
# Out:
# x_train: (763, 6720) float32
# y_train: (763,) int32
# x_val: (90, 6720) float32
# y_val: (90,) int32
# x_test: (90, 6720) float32
# y_test: (90,) int32

# %%
x_train = pd.read_csv(CSV_MANHATTAN24_OUTPUT_PATH +
                      r"\train.csv", header=None)
x_test = pd.read_csv(CSV_MANHATTAN24_OUTPUT_PATH +
                     r"\test.csv", header=None)

y_train = x_train.iloc[:, 0]
x_train = x_train.drop(0, axis=1)
y_test = x_test.iloc[:, 0]
x_test = x_test.drop(0, axis=1)

x_val, x_test, y_val, y_test = train_test_split(
    x_test, y_test, test_size=0.5, random_state=42)

y_train = y_train.to_numpy(np.int32)
x_train = x_train.to_numpy(np.float32)
y_val = y_val.to_numpy(np.int32)
x_val = x_val.to_numpy(np.float32)
y_test = y_test.to_numpy(np.int32)
x_test = x_test.to_numpy(np.float32)

print("x_train:", x_train.shape, x_train.dtype)
print("y_train:", y_train.shape, y_train.dtype)
print("x_val:", x_val.shape, x_val.dtype)
print("y_val:", y_val.shape, y_val.dtype)
print("x_test:", x_test.shape, x_test.dtype)
print("y_test:", y_test.shape, y_test.dtype)
# Out:
# x_train: (763, 5760) float32
# y_train: (763,) int32
# x_val: (90, 5760) float32
# y_val: (90,) int32
# x_test: (90, 5760) float32
# y_test: (90,) int32

# %%
import os
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

FILENAME_PATH = r""
CSV_MANHATTAN_INPUT_PATH = r""
CSV_MANHATTAN28_OUTPUT_PATH = r""

temp_files = []
train_files = []

for root, dirs, files in os.walk(FILENAME_PATH):
    for filename in files:
        if filename.endswith(".mp4"):
            if filename.startswith(missing_files):
                temp_files.append(filename.split('.')[0])
            else:
                train_files.append(filename.split('.')[0])

train_files, test_files = train_test_split(
    train_files, test_size=0.2, random_state=42)
train_files = train_files + temp_files

train = []
for filename in train_files:
    for i in range(1, 6):
        try:
            t = pd.read_csv(CSV_MANHATTAN_INPUT_PATH + "\\" + filename +
                            '_' + str(i) + "_m.csv", header=None).head(240)
        except FileNotFoundError:
            continue
        t = t.to_numpy().flatten()
        t = np.insert(t, 0, filename.split('_')[0]).reshape(1, 6721)
        train.append(t)
train = np.concatenate(train, axis=0)

test = []
for filename in test_files:
    try:
        t = pd.read_csv(CSV_MANHATTAN_INPUT_PATH + "\\" + filename +
                        '_' + str(1) + "_m.csv", header=None).head(240)
    except FileNotFoundError:
        continue
    t = t.to_numpy(dtype=np.int32).flatten()
    t = np.insert(t, 0, filename.replace(
        "_", "")).reshape(1, 6721)
    test.append(t)
test = np.concatenate(test, axis=0)

np.random.seed(42)
np.random.shuffle(train)
np.random.shuffle(test)

os.chdir(CSV_MANHATTAN28_OUTPUT_PATH)
np.savetxt("test2.csv", test, fmt="%d", delimiter=',')
